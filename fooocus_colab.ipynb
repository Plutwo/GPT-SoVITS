# %% [markdown]
# <a href="https://colab.research.google.com/github/Plutwo/GPT-SoVITS/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# !pip install numpy==1.26.4
# !pip install cupy-cuda12x==13.3.0
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 MB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cupy-cuda12x
#     Found existing installation: cupy-cuda12x 14.0.1
#     Uninstalling cupy-cuda12x-14.0.1:
#       Successfully uninstalled cupy-cuda12x-14.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 26.2.1 requires cupy-cuda12x>=13.6.0, but you have cupy-cuda12x 13.3.0 which is incompatible.
# dask-cudf-cu12 26.2.1 requires cupy-cuda12x>=13.6.0, but you have cupy-cuda12x 13.3.0 which is incompatible.
# nx-cugraph-cu12 26.2.0 requires cupy-cuda12x>=13.6.0, but you have cupy-cuda12x 13.3.0 which is incompatible.
# cuml-cu12 26.2.0 requires cupy-cuda12x>=13.6.0, but you have cupy-cuda12x 13.3.0 which is incompatible.
# ...
